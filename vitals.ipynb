# %%
# import pandas to read csv
import pandas as pd

# %%
# load the data file
df1 = pd.read_csv("clinicvitals_emfitvitals.csv")
# Out:
# C:\Users\denni\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5367388 entries, 0 to 5367387
# Data columns (total 16 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   Unnamed: 0      int64
#  1   EMRID           int64
#  2   date            object
#  3   24htime         object
#  4   vitalsBP_syst   float64
#  5   vitalsBP_diast  float64
#  6   unit            object
#  7   vitals_bpm      float64
#  8   vitals_brpm     float64
#  9   vitals_temp     float64
#  10  vitals_spo2     float64
#  11  at              object
#  12  timestamp       float64
#  13  hr              float64
#  14  rr              float64
#  15  act             float64
# dtypes: float64(10), int64(2), object(4)
# memory usage: 655.2+ MB

# %%
# glance at the whole dataset
df1
# Out:
#          Unnamed: 0       EMRID        date   24htime  vitalsBP_syst  \
# 0                 0  2000002769   2/16/2021   3:02:00          109.0
# 1                 1  2000002769   2/16/2021   3:02:00            NaN
# 2                 2  2000002769   2/16/2021   4:02:00          137.0
# 3                 3  2000002769   2/15/2021  17:02:00          131.0
# 4                 4  2000002769   2/15/2021   6:02:00          130.0
# ...             ...         ...         ...       ...            ...
# 5367383     5367383  2000002769  2021-02-22  13:50:00            NaN
# 5367384     5367384  2000002769  2021-02-22  13:50:00            NaN
# 5367385     5367385  2000002769  2021-02-22  13:50:00            NaN
# 5367386     5367386  2000002769  2021-02-22  13:50:00            NaN
# 5367387     5367387  2000002769  2021-02-22  13:50:00            NaN
#
#          vitalsBP_diast  unit  vitals_bpm  vitals_brpm  vitals_temp  \
# 0                  61.0  mmHg         NaN          NaN          NaN
# ...

# %%
# import numpy library
import numpy as np

# %%
# look at the shape/dimension of the df1
print(f'df1 has a shape of ', df1.shape)
# Out:
# df1 has a shape of  (5367388, 16)

# %%
print('Our data has a shape of', df1.shape, 'with the following columns:','\n', df1.columns)
# Out:
# Our data has a shape of (5367388, 16) with the following columns:
#  Index(['Unnamed: 0', 'EMRID', 'date', '24htime', 'vitalsBP_syst',
#        'vitalsBP_diast', 'unit', 'vitals_bpm', 'vitals_brpm', 'vitals_temp',
#        'vitals_spo2', 'at', 'timestamp', 'hr', 'rr', 'act'],
#       dtype='object')

# %% [markdown]
# ### column names
# EMRID = unique patient id \
# date = date vitals were recorded \
# 24htime = time at a specified date the vitals were taken in 24 hour format\
# vitalsBP_syst = blood pressure systolic value\
# vitalsBP_diast = blood pressure diastolic value\
# unit = unit of measure for the vitals\
# vitals_bpm = beats per minute from vital measure\
# vitals_brpm = breathes per min from vital measure\
# vitals_temp = temperatur reading from vital measure\
# vitals_spo2 = oxygen concentration from vital measure\
# at = NaN\
# timestamp = emfit timestamp\
# hr = emfit heart rate\
# rr = emfit respiraory rate\
# act = emfit activity

# %%
# explore the first five observations
df1.head()
# Out:
#    Unnamed: 0       EMRID       date   24htime  vitalsBP_syst  vitalsBP_diast  \
# 0           0  2000002769  2/16/2021   3:02:00          109.0            61.0
# 1           1  2000002769  2/16/2021   3:02:00            NaN             NaN
# 2           2  2000002769  2/16/2021   4:02:00          137.0            68.0
# 3           3  2000002769  2/15/2021  17:02:00          131.0            66.0
# 4           4  2000002769  2/15/2021   6:02:00          130.0            69.0
#
#    unit  vitals_bpm  vitals_brpm  vitals_temp  vitals_spo2   at  timestamp  \
# 0  mmHg         NaN          NaN          NaN          NaN  NaN        NaN
# 1    �F         NaN          NaN         97.6          NaN  NaN        NaN
# 2  mmHg         NaN          NaN          NaN          NaN  NaN        NaN
# 3  mmHg         NaN          NaN          NaN          NaN  NaN        NaN
# 4  mmHg         NaN          NaN          NaN          NaN  NaN        NaN
#
#    hr  rr  act
# 0 NaN NaN  NaN
# ...

# %%
# check for nulls

def df1_details(df):
    b = pd.DataFrame()
    b['NaN/Nulls'] = df1.isnull().sum()
    b['N unique value'] = df1.nunique()
    b['dtype'] = df1.dtypes
    return b
df1_details(df1)
# Out:
#                 NaN/Nulls  N unique value    dtype
# Unnamed: 0              0         5367388    int64
# EMRID                   0              21    int64
# date                    0             158   object
# 24htime                 0            1869   object
# vitalsBP_syst     5366391              78  float64
# vitalsBP_diast    5366373              57  float64
# unit              5360370              10   object
# vitals_bpm        5366459              62  float64
# vitals_brpm       5366605              13  float64
# vitals_temp       5365298              42  float64
# vitals_spo2       5365187              34  float64
# at                   7018          106905   object
# timestamp            7018         2211253  float64
# hr                 219859             113  float64
# rr                 960330             216  float64
# act                  7018            9553  float64

# %%
columns = list(df1)[0:-1]
df1[columns].hist(stacked = False, bins = 100, figsize = (15, 30), layout = (14,2))
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'EMRID'}>],
#        [<AxesSubplot:title={'center':'vitalsBP_syst'}>,
#         <AxesSubplot:title={'center':'vitalsBP_diast'}>],
#        [<AxesSubplot:title={'center':'vitals_bpm'}>,
#         <AxesSubplot:title={'center':'vitals_brpm'}>],
#        [<AxesSubplot:title={'center':'vitals_temp'}>,
#         <AxesSubplot:title={'center':'vitals_spo2'}>],
#        [<AxesSubplot:title={'center':'timestamp'}>,
#         <AxesSubplot:title={'center':'hr'}>],
#        [<AxesSubplot:title={'center':'rr'}>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
emrid = np.unique(df1['EMRID'])

# %%
emrid
# Out:
# array([      1850, 2000002699, 2000002713, 2000002733, 2000002734,
#        2000002735, 2000002736, 2000002741, 2000002769, 2000002770,
#        2000002774, 2000002780, 2050000750, 2050001407, 2050001948,
#        2050002489, 2050002560, 2050002581, 2050002715, 2050002755,
#        2050002792], dtype=int64)

# %%
#
print("There is a total of :", len(emrid), 'patients involved in the study.')
print("The unique values are ", emrid )
# Out:
# There is a total of : 21 patients involved in the study.
# The unique values are  [      1850 2000002699 2000002713 2000002733 2000002734 2000002735
#  2000002736 2000002741 2000002769 2000002770 2000002774 2000002780
#  2050000750 2050001407 2050001948 2050002489 2050002560 2050002581
#  2050002715 2050002755 2050002792]

# %%
import seaborn as sb
import matplotlib.pyplot as plt

# %%
sb.barplot(x= df1.EMRID.value_counts().index, y = df1.EMRID.value_counts().values)
plt.xlabel('EMRID')
plt.ylabel(" COUNT")
plt.show()
